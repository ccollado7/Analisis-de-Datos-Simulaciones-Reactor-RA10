# %% [markdown]
# # Analisis Exploratorio - General PRI

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#Realiza la lectura de los datos que se encuentran en el CSV

datos = pd.read_csv(r"C:\Users\User0044\Practica PRI\1.Analisis General\analisis_general.csv")

# %%
datos.dtypes #Veo el tipo de objeto de las columnas
# Out:
# Tiempo         int64
# FT_1031      float64
# FT_1047      float64
# PDIT_1040    float64
# Qclapeta     float64
# dtype: object

# %%
datos.info() #Obtengo un resumen conciso del DataFrame
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4263 entries, 0 to 4262
# Data columns (total 5 columns):
# Tiempo       4263 non-null int64
# FT_1031      4263 non-null float64
# FT_1047      4263 non-null float64
# PDIT_1040    4263 non-null float64
# Qclapeta     4263 non-null float64
# dtypes: float64(4), int64(1)
# memory usage: 166.6 KB

# %%
datos.isna().sum() #Veo si existen valores nulos en las columnas del DataFrame
# Out:
# Tiempo       0
# FT_1031      0
# FT_1047      0
# PDIT_1040    0
# Qclapeta     0
# dtype: int64

# %%
#Visualizo los primeros 5 conjuntos de datos del Dataset

datos.head()
# Out:
#    Tiempo  FT_1031  FT_1047  PDIT_1040  Qclapeta
# 0     100  3209.99  346.101    402.776 -0.000002
# 1     200  3209.99  346.101    402.776 -0.000002
# 2     300  3209.99  346.101    402.776 -0.000002
# 3     400  3209.99  346.101    402.776 -0.000002
# 4     500  3209.99  346.101    402.776 -0.000002

# %% [markdown]
# La unidad temporal corresponde a [mseg]
#
# La unidad de medida de PDIT corresponde a [kPa]
#
# La unidad de medida de los caudales correspondea a [m3/h]

# %%
tiempo_new = (datos["Tiempo"]/1000) #Modifico la escala temporal para considerar como unidad segundos [s]

# %%
# Visualizo los valores principales del Dataset

datos.describe()
# Out:
#               Tiempo       FT_1031      FT_1047    PDIT_1040      Qclapeta
# count    4263.000000  4.263000e+03  4263.000000  4263.000000  4.263000e+03
# mean   281713.511612  2.955176e+02    24.356158    44.985667  1.295817e+01
# std    132511.039234  8.065348e+02    88.534212    98.456069  1.930243e+01
# min       100.000000  1.681560e-43     0.000000    17.270100 -6.171720e+00
# 25%    180350.000000  2.635050e-20     0.000000    17.342400 -1.707220e-06
# 50%    286900.000000  7.072830e+01     0.000000    17.592200 -5.488960e-08
# 75%    393450.000000  1.541515e+02     0.000000    18.342750  2.794190e+01
# max    500000.000000  3.210000e+03   346.101000   402.776000  5.400000e+01

# %% [markdown]
# ## 1. Analisis FT_1031 - Caudal por el Nucleo

# %%
# Preparo los datos para realizar una primera visualizacion 

t = tiempo_new #Indices
a = datos['FT_1031'] #Valores

plt.xlabel("Tiempo (s)")
plt.ylabel("Caudal (m3/h)")
plt.title("Analisis FT_1031")
plt.plot(t,a)
plt.show()

# %% [markdown]
# ### Zoom 1

# %%
# Zoom 1

plt.plot(t,a)
plt.ylim(-20,700)
plt.xlim(50,350)

plt.xlabel("Tiempo (s)")
plt.ylabel("Caudal (m3/h)")
plt.title("Analisis FT_1031")
plt.show()

# %% [markdown]
# ### Zoom 2

# %%
# Zoom 2

plt.plot(t,a)
plt.ylim(40,350)
plt.xlim(100,290)

plt.xlabel("Tiempo (s)")
plt.ylabel("Caudal (m3/h)")
plt.title("Analisis FT_1031")
plt.show()

# %% [markdown]
# ### Zoom 3

# %%
# Zoom 3

plt.plot(t,a)
plt.ylim(40,105)
plt.xlim(275,300)

plt.xlabel("Tiempo (s)")
plt.ylabel("Caudal (m3/h)")
plt.title("Analisis FT_1031")
plt.show()

# %% [markdown]
# ### Zoom 4

# %%
# Zoom 4

plt.plot(t,a)
plt.ylim(-5,65)
plt.xlim(285,310)

plt.xlabel("Tiempo (s)")
plt.ylabel("Caudal (m3/h)")
plt.title("Analisis FT_1031")
plt.show()

# %% [markdown]
# ## 2. Analisis FT_1047 - Caudal de Interconexion

# %%
# Preparo los datos para realizar una primera visualizacion de los datos

t = tiempo_new #Indices
b = datos['FT_1047'].values #Valores

plt.plot(t,b)
plt.xlabel("Tiempo (s)")
plt.ylabel("Caudal (m3/h)")
plt.title("Analisis FT_1047")
plt.show()

# %% [markdown]
# ### Zoom 1

# %%
# Zoom al inicio del Transitorio

plt.plot(t,b)
plt.ylim(-5,360)
plt.xlim(0,120)

plt.xlabel("Tiempo (s)")
plt.ylabel("Caudal (m3/h)")
plt.title("Analisis FT_1047")
plt.show()

# %% [markdown]
# ## 3. Analisis PDIT_1040 - Caida de presion en el Nucleo

# %%
# Preparo los datos para realizar una primera visualizacion de los datos

t = tiempo_new #Indices
c = datos['PDIT_1040'].values #Valores

plt.plot(t,c)
plt.xlabel("Tiempo (s)")
plt.ylabel("DeltaP (kPa)")
plt.title("Analisis PDIT_1040")
plt.show()

# %% [markdown]
# ### Zoom 1

# %%
# Zoom al inicio del Transitorio

plt.plot(t,c)
plt.ylim(-5,420)
plt.xlim(0,120)

plt.xlabel("Tiempo (s)")
plt.ylabel("DeltaP (kPa)")
plt.title("Analisis PDIT_1040")
plt.show()

# %% [markdown]
# ## 4. Analisis Qclapeta - Caudal por Clapeta

# %%
# Preparo los datos para realizar una primera visualizacion de los datos

t = tiempo_new #Indices
d = datos['Qclapeta'].values #Valores

plt.plot(t,d)
plt.xlabel("Tiempo (s)")
plt.ylabel("Caudal (m3/h)")
plt.title("Analisis Qclapeta")
plt.show()

# %% [markdown]
# ### Zoom 1

# %%
# Zoom 1

plt.plot(t,d)
plt.ylim(-8,60)
plt.xlim(220,500)

plt.xlabel("Tiempo (s)")
plt.ylabel("Caudal (m3/h)")
plt.title("Analisis Qclapeta")
plt.show()

# %% [markdown]
# ### Zoom 2

# %%
# Zoom 2

plt.plot(t,d)
plt.ylim(-8,8)
plt.xlim(200,320)

plt.xlabel("Tiempo (s)")
plt.ylabel("Caudal (m3/h)")
plt.title("Analisis Qclapeta")
plt.show()

# %% [markdown]
# ### Zoom 3

# %%
# Zoom 3

plt.plot(t,d)
plt.ylim(-6,-3)
plt.xlim(275,290)

plt.xlabel("Tiempo (s)")
plt.ylabel("Caudal (m3/h)")
plt.title("Analisis Qclapeta")
plt.show()

# %% [markdown]
# ## 5. Analisis en Conjunto

# %%
# Grafico en conjunto

plt.plot(t,a,label = "FT_1031") # Primario
plt.plot(t,b,label = "FT_1047") # Interconexion
plt.plot(t,d,label = "Qclapeta") # Clapetas

plt.xlabel("Tiempo (s)")
plt.ylabel("Caudal (m3/h)")
plt.title("Analisis de Caudales")
plt.legend()
plt.show()

# %% [markdown]
# ### Zoom 1

# %%
# Zoom 1

plt.plot(t,a,label = "FT_1031") # Primario
plt.plot(t,b,label = "FT_1047") # Interconexion
plt.plot(t,d,label = "Qclapeta") # Clapetas

plt.xlim(80,120)
plt.ylim(-10,500)

plt.xlabel("Tiempo (s)")
plt.ylabel("Caudal (m3/h)")
plt.title("Analisis de Caudales")
plt.legend()
plt.show()

# %% [markdown]
# ### Zoom 2

# %%
# Zoom 2

plt.plot(t,a,label = "FT_1031") # Primario
plt.plot(t,b,label = "FT_1047") # Interconexion
plt.plot(t,d,label = "Qclapeta") # Clapetas

plt.xlim(103,105)
plt.ylim(-2,5)

plt.xlabel("Tiempo (s)")
plt.ylabel("Caudal (m3/h)")
plt.title("Analisis de Caudales")
plt.legend()
plt.show()

# %% [markdown]
# ### Zoom 3

# %%
# Zoom 3

plt.plot(t,a,label = "FT_1031") # Primario
plt.plot(t,b,label = "FT_1047") # Interconexion
plt.plot(t,d,label = "Qclapeta") # Clapetas

plt.xlim(297,310)
plt.ylim(-2,10)

plt.xlabel("Tiempo (s)")
plt.ylabel("Caudal (m3/h)")
plt.title("Analisis de Caudales")
plt.legend()
plt.show()

# %% [markdown]
# ### Zoom 4

# %%
# Zoom 4

plt.plot(t,a,label = "FT_1031") # Primario
plt.plot(t,b,label = "FT_1047") # Interconexion
plt.plot(t,d,label = "Qclapeta") # Clapetas

plt.xlim(210,300)
plt.ylim(-20,150)

plt.xlabel("Tiempo (s)")
plt.ylabel("Caudal (m3/h)")
plt.title("Analisis de Caudales")
plt.legend()
plt.show()

# %% [markdown]
# # 6. Analisis de Valores Particulares

# %% [markdown]
# ## 6.1 Analisis Clapetas

# %% [markdown]
# ### 6.1.1 Caudal Positivo (+) por Clapeta

# %%
Qclapeta_positivo = datos["Qclapeta"] >= 0 #Filtro el DataFrame por la valores mayores o iguales a cero de Qclapeta

# %%
Qclapeta_positivo.head() #Visualizo el resultado de la operacion anterior por medio de un array booleano
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# Name: Qclapeta, dtype: bool

# %%
datos_Qclapeta_positivo = datos[Qclapeta_positivo] #Utilizando el array booleano filtro todos los datos de DataFrame

# %%
datos_Qclapeta_positivo.head() #Visualizo los primeros valores
# Out:
#       Tiempo  FT_1031  FT_1047  PDIT_1040  Qclapeta
# 2261  299900  6.10485      0.0    17.5173  0.017021
# 2262  300000  5.80650      0.0    17.5169  0.051681
# 2263  300100  5.52270      0.0    17.5166  0.086401
# 2264  300200  5.25277      0.0    17.5162  0.121131
# 2265  300300  4.99602      0.0    17.5159  0.155899

# %%
datos_Qclapeta_positivo.loc[2261] #Primera fila del DataFrame filtrodo
# Out:
# Tiempo       299900.000000
# FT_1031           6.104850
# FT_1047           0.000000
# PDIT_1040        17.517300
# Qclapeta          0.017021
# Name: 2261, dtype: float64

# %%
#Grafico de valores positivos

plt.plot(datos_Qclapeta_positivo["Qclapeta"])
plt.show()

# %% [markdown]
# ### 6.1.2 Caudal Negativo (-) por Clapeta

# %%
Qclapeta_negativo = datos["Qclapeta"] < 0 #Filtro el DataFrame por la valores menores a cero de Qclapeta

# %%
Qclapeta_negativo.head() #Visualizo el resultado de la operacion anterior por medio de un array booleano
# Out:
# 0    True
# 1    True
# 2    True
# 3    True
# 4    True
# Name: Qclapeta, dtype: bool

# %%
datos_Qclapeta_negativo = datos[Qclapeta_negativo]

# %%
datos_Qclapeta_negativo.head() #Primera fila del DataFrame filtrodo
# Out:
#    Tiempo  FT_1031  FT_1047  PDIT_1040  Qclapeta
# 0     100  3209.99  346.101    402.776 -0.000002
# 1     200  3209.99  346.101    402.776 -0.000002
# 2     300  3209.99  346.101    402.776 -0.000002
# 3     400  3209.99  346.101    402.776 -0.000002
# 4     500  3209.99  346.101    402.776 -0.000002

# %%
#Grafico de valores negativos

plt.plot(datos_Qclapeta_negativo["Qclapeta"])
plt.show()

# %% [markdown]
# ## 6.2 Analisis Caudal por el Nucleo

# %%
primer_valor = datos[0:1] #Veo el primer valor de la simulacion con el reactor en condicion estacionaria

# %%
primer_valor #Visualizo la 1° fila del DataFrame
# Out:
#    Tiempo  FT_1031  FT_1047  PDIT_1040  Qclapeta
# 0     100  3209.99  346.101    402.776 -0.000002

# %%
primer_valor_Qprimario = primer_valor["FT_1031"] #Filtro el valor del caudal del Primario

# %%
primer_valor_Qprimario
# Out:
# 0    3209.99
# Name: FT_1031, dtype: float64

# %%
Qnucleo_TRIP1 = datos["FT_1031"] > (3209.99*0.9) #Filtro el DataFrame por la valores menores al caudal nominal del Primario

# %%
Qnucleo_TRIP1.head()
# Out:
# 0    True
# 1    True
# 2    True
# 3    True
# 4    True
# Name: FT_1031, dtype: bool

# %%
datos_Qprimario_TRIP1 = datos[Qnucleo_TRIP1]

# %%
datos_Qprimario_TRIP1.head()
# Out:
#    Tiempo  FT_1031  FT_1047  PDIT_1040  Qclapeta
# 0     100  3209.99  346.101    402.776 -0.000002
# 1     200  3209.99  346.101    402.776 -0.000002
# 2     300  3209.99  346.101    402.776 -0.000002
# 3     400  3209.99  346.101    402.776 -0.000002
# 4     500  3209.99  346.101    402.776 -0.000002

# %%
plt.plot(datos_Qprimario_TRIP1["FT_1031"])
plt.show()
